# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Chamando os logs

# %%
df1 = pd.read_csv('custo_computacional.csv')
df2 = pd.read_csv('custo_computacional2.csv')

# %%
df1
# Out:
#     num_pontos  tempo_ms
# 0            3  0.047723
# 1            4  0.088123
# 2            5  0.083009
# 3            6  0.070679
# 4            7  0.119137
# 5            8  0.161467
# 6            9  0.120106
# 7           10  0.219954
# 8           11  0.132837
# 9           12  0.381898
# 10          13  0.240969
# 11          14  0.197436
# 12          15  0.216079

# %%
df2
# Out:
#     num_pontos  tempo_ms
# 0            3  0.041449
# 1            4  0.104573
# 2            5  0.103267
# 3            6  0.077313
# 4            7  0.095063
# 5            8  0.104696
# 6            9  0.099525
# 7           10  0.125819
# 8           11  0.145704
# 9           12  0.162159
# 10          13  0.172514
# 11          14  0.173030
# 12          15  0.367930

# %% [markdown]
# ## Gráficos de tempo de calculo por numero de pontos

# %%
plt.figure(figsize=(12, 6))

plt.plot(df1['num_pontos'], df1['tempo_ms'], 'ro-',
         label='Pontos Próximos (dados)', linewidth=2, markersize=6)
plt.plot(df2['num_pontos'], df2['tempo_ms'], 'bs-',
         label='Pontos Distantes (dados)', linewidth=2, markersize=6)

z1 = np.polyfit(df1['num_pontos'], df1['tempo_ms'], 2)
p1 = np.poly1d(z1)
z2 = np.polyfit(df2['num_pontos'], df2['tempo_ms'], 2)
p2 = np.poly1d(z2)

x_smooth = np.linspace(3, 15, 100)
plt.plot(x_smooth, p1(x_smooth), 'r--', alpha=0.7,
         label='Tendência Pontos Próximos')
plt.plot(x_smooth, p2(x_smooth), 'b--', alpha=0.7,
         label='Tendência Pontos Distantes')

plt.xlabel('Número de Pontos')
plt.ylabel('Tempo (ms)')
plt.title('Custo Computacional com Linhas de Tendência')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
